# %% [markdown]
# # Web Scrape Video Games
# > <a href=#imports>Import Libraries</a>
#
# > <a href=#webscrabing>Web Scraping</a>
#
# > <a href=#merge>Merging Data</a>
#
# > <a href=#EDA>Explratory Data Analysis (EDA)</a>

# %% [markdown]
# # <a name=imports> Import Libraries</a>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # <a name=webscrabing>Web Scraping</a>

# %%
url = "https://www.imdb.com/search/title/?title_type=video_game"

response = requests.get(url)
response.status_code
page = response.text
soup = BeautifulSoup(page, "lxml")

# %%
def clean_num(s):
    """cleans text scraped from website
    
    Parameters:
    s (String): raw text

    Returns:
    String: cleaned digit text

    """ 

    if s is None:
        return s
    return "".join(re.findall('\d*\.?\d+',s))

def get_data(block, tag, class_text):
    """fetch data from tag and its associated class
    
    Parameters:
    block (int): Book item 
    tag (String): tag for element we want to fetch
    class_text (String): class for element we want to fetch

    Returns:
    String: data text fetched

    """ 
    try:
        return block.find(tag, class_ = class_text).text.replace('(','').replace(')','')
    except AttributeError:
        return ""
    return

def get_data_a_tag(i, tag, class_text):    
    try:
        return i.find(tag, class_ = class_text).a.text
    except AttributeError:
        return ""
    return
def get_data_strong_tag(i, tag, class_text):    
    try:
        return i.find(tag, class_ = class_text).strong.text
    except AttributeError:
        return ""
    return
def get_data_descr(i, tag, class_text):    
    try:
        return i.find_all(tag, class_ = class_text)[1].text.strip()
    except AttributeError:
        return ""
    return


def get_data_votes(i, tag, class_text):    
    try:
        return i.find(tag, class_ = class_text).text.split()[1].replace(',','')
    except AttributeError:
        return ""
    return

# %%
    
Vgame_list = []

for i in (soup.find_all('div','lister-item mode-advanced')):
    Name = get_data_a_tag(i, "h3","lister-item-header")
    year = get_data(i, "span", "lister-item-year text-muted unbold").split()[0]
    Gtype = get_data(i, "p", "text-muted").strip()
    rate = clean_num(get_data_strong_tag(i, "div","ratings-bar"))
    votes = clean_num(get_data_votes(i, "p","sort-num_votes-visible"))
    
    headers = ['Name', 'year', 'game_type', 'rate','votes']
    Vgame_dict = dict(zip(headers, [ Name,
                                    year,
                                    Gtype,
                                    rate,
                                    votes]))
    Vgame_list.append(Vgame_dict)

# %%
vedioGame = pd.DataFrame(Vgame_list) #transpose
vedioGame
# Out:
#                                                  Name   year  \
# 0                    Marvel's Guardians of the Galaxy   2021
# 1                       Grand Theft Auto: San Andreas   2004
# 2                              Red Dead Redemption II   2018
# 3                              Call of Duty: Vanguard   2021
# 4                                       Halo Infinite   2021
# 5                                  Grand Theft Auto V   2013
# 6                                           Far Cry 6   2021
# 7                                     Death Stranding   2019
# 8                             The Last of Us: Part II   2020
# 9                                        Ghostbusters   2009
# 10                        Grand Theft Auto: Vice City   2002
# 11                                   Battlefield 2042   2021
# 12                                     Cyberpunk 2077   2020
# 13                                  League of Legends   2009
# 14                                         Spider-Man   2018
# 15                              Detroit: Become Human   2018
# 16                          Spider-Man: Miles Morales   2020
# 17                                     The Last of Us   2013
# 18                          Assassin's Creed Valhalla   2020
# 19                              Resident Evil Village   2021
# 20                       Star Wars Jedi: Fallen Order   2019
# 21                                         Until Dawn   2015
# 22                  The Dark Pictures: House of Ashes   2021
# 23                                         God of War   2018
# 24                                  Ghost of Tsushima   2020
# 25                               Grand Theft Auto III   2001
# 26                        The Elder Scrolls V: Skyrim   2011
# 27                                Grand Theft Auto IV   2008
# 28                              Wiedzmin 3: Dziki Gon   2015
# 29                                  Horizon Zero Dawn   2017
# 30                              Batman: Arkham Knight   2015
# 31                                          Far Cry 3   2012
# 32                                       It Takes Two   2021
# 33                                  Marvel's Avengers   2020
# 34                         Uncharted 4: A Thief's End   2016
# 35  Grand Theft Auto: The Trilogy - The Definitive...   2021
# 36                           Final Fantasy VII Remake   2020
# 37                                        Mass Effect   2007
# 38                                Red Dead Redemption   2010
# 39                     Command & Conquer: Red Alert 3   2008
# 40                                        Squadron 42  Video
# 41                     Mass Effect: Legendary Edition   2021
# 42                       Call of Duty: Modern Warfare   2019
# 43                                     Genshin Impact   2020
# 44                                          Fallout 4   2015
# 45                                         L.A. Noire   2011
# 46                          Mafia: Definitive Edition   2020
# 47                                          Far Cry 5   2018
# 48                                Batman: Arkham City   2011
# 49                               God of War: Ragnarök   2022
#
#                                             game_type rate  votes
# 0                           Action, Adventure, Comedy  9.1    925
# 1                                       Action, Crime  9.4  37733
# 2                            Action, Adventure, Crime  9.7  28865
# 3                          Action, Adventure, History  6.4    496
# 4   Action, Adventure, Sci-Fi            \n|\nComp...
# 5                                Action, Crime, Drama  9.5  55637
# 6                                   Action, Adventure  8.1    812
# 7                            Action, Adventure, Drama  8.9   6982
# 8               banned\n|\n\nAction, Adventure, Drama  8.3  26167
# 9                           Action, Adventure, Comedy  8.5   2870
# 10                               Action, Crime, Drama  9.2  25150
# 11                          Action, Adventure, Sci-Fi  3.5    201
# 12                               Action, Crime, Drama  7.9   5940
# 13                         Action, Adventure, Fantasy  7.3   2428
# 14                         Action, Adventure, Fantasy  9.2  16894
# 15                           Action, Adventure, Drama  9.2  14259
# 16                           Action, Adventure, Crime  8.5   3495
# 17                           Action, Adventure, Drama  9.7  55838
# 18                         Action, Adventure, Fantasy  8.2   2735
# 19                         Action, Adventure, Fantasy  8.8   3249
# 20                           Action, Adventure, Drama  8.6   8500
# 21                          Horror, Mystery, Thriller  8.8  12975
# 22                          Action, Adventure, Horror  7.9    491
# 23                           Action, Adventure, Drama  9.6  21393
# 24                           Action, Adventure, Drama  9.3   6023
# 25                               Action, Crime, Drama  8.7  15038
# 26                         Action, Adventure, Fantasy  9.4  27882
# 27                               Action, Crime, Drama  8.9  33334
# 28              banned\n|\n\nAction, Adventure, Drama  9.7  23109
# 29                         Action, Adventure, Mystery  9.1  11672
# 30                           Action, Adventure, Crime  9.0  16697
# 31                                  Action, Adventure  8.9  17561
# 32                           Adventure, Comedy, Drama  9.3    933
# 33                         Action, Adventure, Fantasy  6.4   1829
# 34                           Action, Adventure, Drama  9.5  25021
# 35                               Action, Crime, Drama  3.1    310
# 36                         Action, Adventure, Fantasy  9.1   2983
# 37                          Action, Adventure, Sci-Fi  9.2  17371
# 38              banned\n|\n\nAction, Adventure, Crime  9.4  25163
# 39                                Action, Sci-Fi, War  7.6   1978
# 40           Action, Sci-Fi            \n|\nAnnounced
# 41                                             Sci-Fi  9.7    747
# 42                        Action, Adventure, Thriller  8.4   4313
# 43                         Action, Adventure, Fantasy  7.9    708
# 44                           Action, Adventure, Drama  8.6  11849
# 45                  banned\n|\n\nAction, Crime, Drama  8.7  14887
# 46                               Action, Crime, Drama  8.5   1701
# 47                         Action, Adventure, Western  8.0   5907
# 48                           Action, Adventure, Crime  9.4  28766
# 49  Action, Adventure, Drama            \n|\nPost-...

# %%
def get_movie_dict(link):

    #Create full url to scrape
    url =link
    
    #Request HTML and parse
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")
  
    
    for i in (soup.find_all('div','lister-item mode-advanced')):        
        Name = get_data_a_tag(i, "h3","lister-item-header")
        year = get_data(i, "span", "lister-item-year text-muted unbold").split()[0]
        Gtype = get_data(i, "p", "text-muted").strip()
        rate = clean_num(get_data_strong_tag(i, "div","ratings-bar"))
        votes = clean_num(get_data_votes(i, "p","sort-num_votes-visible"))
    
        headers = ['Name', 'year', 'game_type', 'rate','votes']
        #Create game vedio dictionary and return
        movie_dict = dict(zip(headers, [ Name,
                                    year,
                                    Gtype,
                                    rate,
                                    votes]))
        Vgame_list.append(movie_dict) 

    return movie_dict

# %%
get_movie_dict("https://www.imdb.com/search/title/?title_type=video_game&start=51&ref_=adv_nxt")
# Out:
# {'Name': 'Teiruzu obu Araizu',
#  'year': '2021',
#  'game_type': 'Action, Adventure, Fantasy',
#  'rate': '8.8',
#  'votes': '146'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=101&ref_=adv_nxt')
# Out:
# {'Name': "Assassin's Creed II",
#  'year': '2009',
#  'game_type': 'Action, Adventure, Fantasy',
#  'rate': '9.1',
#  'votes': '21858'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=151&ref_=adv_nxt')
# Out:
# {'Name': 'Lost Judgment',
#  'year': '2021',
#  'game_type': 'Action, Adventure, Crime',
#  'rate': '8.8',
#  'votes': '92'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=201&ref_=adv_nxt')
# Out:
# {'Name': 'Devil May Cry 5',
#  'year': '2019',
#  'game_type': 'Action, Adventure, Fantasy',
#  'rate': '8.6',
#  'votes': '1725'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=251&ref_=adv_nxt')
# Out:
# {'Name': 'Outlast 2',
#  'year': '2017',
#  'game_type': 'Horror, Mystery, Thriller',
#  'rate': '7.6',
#  'votes': '1940'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=301&ref_=adv_nxt')
# Out:
# {'Name': 'Faiâ emuburemu: Fuuka setsugetsu',
#  'year': '2019',
#  'game_type': 'Adventure, Drama, Fantasy',
#  'rate': '8.9',
#  'votes': '541'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=351&ref_=adv_nxt')
# Out:
# {'Name': 'NBA 2K21',
#  'year': '2020',
#  'game_type': 'Sport',
#  'rate': '4.5',
#  'votes': '292'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=401&ref_=adv_nxt')
# Out:
# {'Name': 'Ultimate Spider-Man',
#  'year': '2005',
#  'game_type': 'Action, Adventure, Crime',
#  'rate': '7.7',
#  'votes': '1251'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=451&ref_=adv_nxt')
# Out:
# {'Name': 'Sally Face',
#  'year': '2016',
#  'game_type': 'Adventure, Drama, Horror',
#  'rate': '8.5',
#  'votes': '52'}

# %%
vedioGamePages = pd.DataFrame(Vgame_list) #transpose
vedioGamePages
# Out:
#                                              Name  year  \
# 0                Marvel's Guardians of the Galaxy  2021
# 1                   Grand Theft Auto: San Andreas  2004
# 2                          Red Dead Redemption II  2018
# 3                          Call of Duty: Vanguard  2021
# 4                                   Halo Infinite  2021
# ..                                            ...   ...
# 495                        Alice: Madness Returns  2011
# 496                                     GreedFall  2019
# 497  Guardians of the Galaxy: The Telltale Series  2017
# 498             Dungeons & Dragons: Dark Alliance  2021
# 499                                    Sally Face  2016
#
#                                              game_type rate  votes
# 0                            Action, Adventure, Comedy  9.1    925
# 1                                        Action, Crime  9.4  37733
# 2                             Action, Adventure, Crime  9.7  28865
# 3                           Action, Adventure, History  6.4    496
# 4    Action, Adventure, Sci-Fi            \n|\nComp...
# ..                                                 ...  ...    ...
# 495                         Action, Adventure, Fantasy  8.3   1219
# 496                         Action, Adventure, Fantasy  7.1    384
# 497                          Action, Adventure, Comedy  7.8    789
# 498                         Action, Adventure, Fantasy  4.4     38
# 499                           Adventure, Drama, Horror  8.5     52
#
# [500 rows x 5 columns]

# %%
vedioGamePages.to_csv('videogame_webscraping.csv')

# %%
vedioGamePages.Name=vedioGamePages.Name.str.lower()
vedioGamePages.head()
# Out:
#                                Name  year  \
# 0  marvel's guardians of the galaxy  2021
# 1     grand theft auto: san andreas  2004
# 2            red dead redemption ii  2018
# 3            call of duty: vanguard  2021
# 4                     halo infinite  2021
#
#                                            game_type rate  votes
# 0                          Action, Adventure, Comedy  9.1    925
# 1                                      Action, Crime  9.4  37733
# 2                           Action, Adventure, Crime  9.7  28865
# 3                         Action, Adventure, History  6.4    496
# 4  Action, Adventure, Sci-Fi            \n|\nComp...

# %%
vedioGamePages
# Out:
#                                              Name  year  \
# 0                marvel's guardians of the galaxy  2021
# 1                   grand theft auto: san andreas  2004
# 2                          red dead redemption ii  2018
# 3                          call of duty: vanguard  2021
# 4                                   halo infinite  2021
# ..                                            ...   ...
# 495                        alice: madness returns  2011
# 496                                     greedfall  2019
# 497  guardians of the galaxy: the telltale series  2017
# 498             dungeons & dragons: dark alliance  2021
# 499                                    sally face  2016
#
#                                              game_type rate  votes
# 0                            Action, Adventure, Comedy  9.1    925
# 1                                        Action, Crime  9.4  37733
# 2                             Action, Adventure, Crime  9.7  28865
# 3                           Action, Adventure, History  6.4    496
# 4    Action, Adventure, Sci-Fi            \n|\nComp...
# ..                                                 ...  ...    ...
# 495                         Action, Adventure, Fantasy  8.3   1219
# 496                         Action, Adventure, Fantasy  7.1    384
# 497                          Action, Adventure, Comedy  7.8    789
# 498                         Action, Adventure, Fantasy  4.4     38
# 499                           Adventure, Drama, Horror  8.5     52
#
# [500 rows x 5 columns]

# %%
df=pd.read_csv('vgsales.csv') #data from kaggle

# %%
df.Name=df.Name.str.lower()
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                wii sports      Wii  2006.0        Sports  Nintendo
# 1     2         super mario bros.      NES  1985.0      Platform  Nintendo
# 2     3            mario kart wii      Wii  2008.0        Racing  Nintendo
# 3     4         wii sports resort      Wii  2009.0        Sports  Nintendo
# 4     5  pokemon red/pokemon blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.drop([ 'Year', 'Genre','Publisher'], axis=1, inplace=True)

# %% [markdown]
# # <a name=merge>Merging Data</a>

# %%
mer_vidgame=vedioGamePages.merge(df, on='Name')

# %%
mer_vidgame.head()
# Out:
#                             Name  year             game_type rate  votes  \
# 0  grand theft auto: san andreas  2004         Action, Crime  9.4  37733
# 1  grand theft auto: san andreas  2004         Action, Crime  9.4  37733
# 2  grand theft auto: san andreas  2004         Action, Crime  9.4  37733
# 3  grand theft auto: san andreas  2004         Action, Crime  9.4  37733
# 4             grand theft auto v  2013  Action, Crime, Drama  9.5  55637
#
#    Rank Platform  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0    18      PS2      9.43      0.40      0.41        10.57         20.81
# 1   875       XB      1.26      0.61      0.00         0.09          1.95
# 2  2122       PC      0.00      0.92      0.00         0.05          0.98
# 3  9829     X360      0.08      0.03      0.00         0.01          0.12
# 4    17      PS3      7.01      9.27      0.97         4.14         21.40

# %%
df1=pd.DataFrame(mer_vidgame)

# %% [markdown]
# # <a name=EDA>Explratory data analysis(EDA)</a>

# %%
df1.shape
# Out:
# (658, 12)

# %%
df1['game_type'].tolist()
# Out:
# ['Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Horror, Mystery, Thriller',
#  'Action, Adventure, Drama',
#  'banned\n|\n\nAction, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'banned\n|\n\nAction, Adventure, Crime',
#  'banned\n|\n\nAction, Adventure, Crime',
#  'Action, Sci-Fi, War',
#  'Action, Sci-Fi, War',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'banned\n|\n\nAction, Crime, Drama',
#  'banned\n|\n\nAction, Crime, Drama',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Mystery',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Sci-Fi',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Comedy, Drama',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Drama, Mystery, Sci-Fi',
#  'Drama, Mystery, Sci-Fi',
#  'Drama, Mystery, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Drama            \n|\nAnnounced',
#  'Action, Adventure, Drama            \n|\nAnnounced',
#  'Action, Adventure, Drama            \n|\nAnnounced',
#  'Action, Adventure, Drama            \n|\nAnnounced',
#  'Action, Adventure, Drama            \n|\nAnnounced',
#  'Action, Adventure, Drama            \n|\nAnnounced',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'banned\n|\n\nCrime, Drama, Mystery',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Horror, Sci-Fi, Thriller',
#  'Horror, Sci-Fi, Thriller',
#  'Horror, Sci-Fi, Thriller',
#  'Horror, Sci-Fi, Thriller',
#  'Horror, Sci-Fi, Thriller',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Adventure, Comedy, Sci-Fi',
#  'Adventure, Comedy, Sci-Fi',
#  'Adventure, Comedy, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Crime, Thriller',
#  'Action, Crime, Thriller',
#  'Action, Mystery, Sci-Fi',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, War',
#  'Action, War',
#  'Action, War',
#  'Action, War',
#  'Action, War',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Thriller',
#  '130 min\n|\n\nAction, Adventure, Thriller',
#  'banned\n|\n\nAction, Adventure, Thriller',
#  'banned\n|\n\nAction, Adventure, Thriller',
#  'banned\n|\n\nAction, Adventure, Thriller',
#  'banned\n|\n\nAction, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Drama, Horror, Mystery',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Drama',
#  'Action, Comedy, Horror',
#  'Action, Comedy, Horror',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Sci-Fi',
#  'Action, Crime, Sci-Fi',
#  'Action, Crime, Sci-Fi',
#  'Action, Crime, Sci-Fi',
#  'Action, Crime, Sci-Fi',
#  'Action, Crime, Sci-Fi',
#  'Action, Mystery, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Horror, Mystery',
#  'Action, Horror, Mystery',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'banned\n|\n\nAction, Adventure, Comedy',
#  'banned\n|\n\nAction, Adventure, Comedy',
#  'banned\n|\n\nAction, Adventure, Comedy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Fantasy',
#  'Animation, Action, Adventure',
#  'Animation, Action, Adventure',
#  'Animation, Action, Adventure',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Horror, War',
#  'Action, Horror, War',
#  'Action, Horror, War',
#  'Action, Horror, War',
#  'Action, Horror, War',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Crime',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Adventure, Drama',
#  'R18\n|\n\nCrime, Horror, Thriller',
#  'R18\n|\n\nCrime, Horror, Thriller',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, War',
#  'Action, War',
#  'Action, War',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Drama, Mystery',
#  'Action, Drama, Mystery',
#  'Action, Drama, Mystery',
#  'Action, Crime, Sci-Fi',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Crime, Thriller',
#  'Action, Crime, Drama',
#  'Action, Sci-Fi, Thriller',
#  'Action, Sci-Fi, Thriller',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Sci-Fi, War',
#  'Action, Sci-Fi, War',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Crime, Sport',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Horror, Mystery',
#  'Action, Horror, Mystery',
#  'Action, Horror, Mystery',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Drama, Horror, Mystery',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'banned\n|\n\nHorror, Mystery, Thriller',
#  'banned\n|\n\nHorror, Mystery, Thriller',
#  'banned\n|\n\nHorror, Mystery, Thriller',
#  'Action, Adventure, Sci-Fi',
#  'Crime, Mystery',
#  'Crime, Mystery',
#  'Crime, Mystery',
#  'Crime, Mystery',
#  'Adventure, Mystery, Thriller',
#  'Adventure, Mystery, Thriller',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Adventure, Mystery',
#  'Adventure, Mystery',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Animation, Action, Adventure',
#  'Animation, Action, Adventure',
#  'Crime, Horror, Mystery',
#  'Crime, Horror, Mystery',
#  'Crime, Horror, Mystery',
#  'Action, Adventure, Fantasy',
#  'Drama, Horror, Mystery',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Sci-Fi, War',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, War',
#  'Action, War',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy']

# %%
df1['game_type']=df1['game_type'].str.replace('banned\n|\n\n','')
df1['game_type']=df1['game_type'].str.replace('\n|\nAnnounced','')
df1['game_type']=df1['game_type'].str.replace('|','')
df1['game_type']=df1['game_type'].str.replace('Announced','')
df1['game_type']=df1['game_type'].str.replace('130 min\n|\n\n','')
# Out:
# <ipython-input-29-439f93edc8ac>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['game_type']=df1['game_type'].str.replace('banned\n|\n\n','')
# <ipython-input-29-439f93edc8ac>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['game_type']=df1['game_type'].str.replace('\n|\nAnnounced','')
# <ipython-input-29-439f93edc8ac>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df1['game_type']=df1['game_type'].str.replace('|','')
# <ipython-input-29-439f93edc8ac>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['game_type']=df1['game_type'].str.replace('130 min\n|\n\n','')

# %%
df1
# Out:
#                                  Name  year                   game_type rate  \
# 0       grand theft auto: san andreas  2004               Action, Crime  9.4
# 1       grand theft auto: san andreas  2004               Action, Crime  9.4
# 2       grand theft auto: san andreas  2004               Action, Crime  9.4
# 3       grand theft auto: san andreas  2004               Action, Crime  9.4
# 4                  grand theft auto v  2013        Action, Crime, Drama  9.5
# ..                                ...   ...                         ...  ...
# 653  prince of persia: warrior within  2004  Action, Adventure, Fantasy  8.6
# 654                   ratchet & clank  2016   Action, Adventure, Comedy  8.1
# 655            alice: madness returns  2011  Action, Adventure, Fantasy  8.3
# 656            alice: madness returns  2011  Action, Adventure, Fantasy  8.3
# 657            alice: madness returns  2011  Action, Adventure, Fantasy  8.3
#
#      votes  Rank Platform  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0    37733    18      PS2      9.43      0.40      0.41        10.57
# 1    37733   875       XB      1.26      0.61      0.00         0.09
# 2    37733  2122       PC      0.00      0.92      0.00         0.05
# 3    37733  9829     X360      0.08      0.03      0.00         0.01
# 4    55637    17      PS3      7.01      9.27      0.97         4.14
# ..     ...   ...      ...       ...       ...       ...          ...
# 653   3684  7718       GC      0.15      0.04      0.00         0.01
# 654   2177   405      PS2      1.44      1.01      0.57         0.30
# 655   1219  3352      PS3      0.22      0.25      0.04         0.09
# 656   1219  3956     X360      0.27      0.15      0.04         0.04
# 657   1219  9789       PC      0.00      0.10      0.00         0.02
#
#      Global_Sales
# 0           20.81
# 1            1.95
# 2            0.98
# 3            0.12
# 4           21.40
# ..            ...
# 653          0.20
# 654          3.33
# 655          0.60
# 656          0.50
# 657          0.12
#
# [658 rows x 12 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 658 entries, 0 to 657
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          658 non-null    object
#  1   year          658 non-null    object
#  2   game_type     658 non-null    object
#  3   rate          658 non-null    object
#  4   votes         658 non-null    object
#  5   Rank          658 non-null    int64
#  6   Platform      658 non-null    object
#  7   NA_Sales      658 non-null    float64
#  8   EU_Sales      658 non-null    float64
#  9   JP_Sales      658 non-null    float64
#  10  Other_Sales   658 non-null    float64
#  11  Global_Sales  658 non-null    float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 66.8+ KB

# %%
df1['year'] = pd.to_numeric(df1['year'], errors='coerce')

# %%
df1['rate'] = pd.to_numeric(df1['rate'], errors='coerce')

# %%
df1['votes'] = pd.to_numeric(df1['votes'], errors='coerce')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 658 entries, 0 to 657
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          658 non-null    object
#  1   year          652 non-null    float64
#  2   game_type     658 non-null    object
#  3   rate          652 non-null    float64
#  4   votes         652 non-null    float64
#  5   Rank          658 non-null    int64
#  6   Platform      658 non-null    object
#  7   NA_Sales      658 non-null    float64
#  8   EU_Sales      658 non-null    float64
#  9   JP_Sales      658 non-null    float64
#  10  Other_Sales   658 non-null    float64
#  11  Global_Sales  658 non-null    float64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 66.8+ KB

# %%
df1.describe()
# Out:
#               year        rate         votes          Rank    NA_Sales  \
# count   652.000000  652.000000    652.000000    658.000000  658.000000
# mean   2009.914110    8.150613   7766.173313   3775.724924    1.044635
# std       4.941935    0.895928   8413.975509   3914.957989    1.885704
# min    1985.000000    3.100000     76.000000      2.000000    0.000000
# 25%    2007.000000    7.800000   2340.000000    688.250000    0.132500
# 50%    2011.000000    8.200000   5230.000000   2355.000000    0.430000
# 75%    2013.000000    8.700000   9715.000000   5605.250000    1.177500
# max    2023.000000    9.700000  55838.000000  16375.000000   29.080000
#
#          EU_Sales    JP_Sales  Other_Sales  Global_Sales
# count  658.000000  658.000000   658.000000    658.000000
# mean     0.657979    0.068480     0.236429      2.007933
# std      0.975303    0.319265     0.543974      3.203586
# min      0.000000    0.000000     0.000000      0.010000
# 25%      0.090000    0.000000     0.022500      0.320000
# 50%      0.295000    0.000000     0.085000      0.885000
# 75%      0.817500    0.040000     0.250000      2.307500
# max      9.270000    6.810000    10.570000     40.240000

# %%
df1
# Out:
#                                  Name    year                   game_type  \
# 0       grand theft auto: san andreas  2004.0               Action, Crime
# 1       grand theft auto: san andreas  2004.0               Action, Crime
# 2       grand theft auto: san andreas  2004.0               Action, Crime
# 3       grand theft auto: san andreas  2004.0               Action, Crime
# 4                  grand theft auto v  2013.0        Action, Crime, Drama
# ..                                ...     ...                         ...
# 653  prince of persia: warrior within  2004.0  Action, Adventure, Fantasy
# 654                   ratchet & clank  2016.0   Action, Adventure, Comedy
# 655            alice: madness returns  2011.0  Action, Adventure, Fantasy
# 656            alice: madness returns  2011.0  Action, Adventure, Fantasy
# 657            alice: madness returns  2011.0  Action, Adventure, Fantasy
#
#      rate    votes  Rank Platform  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0     9.4  37733.0    18      PS2      9.43      0.40      0.41        10.57
# 1     9.4  37733.0   875       XB      1.26      0.61      0.00         0.09
# 2     9.4  37733.0  2122       PC      0.00      0.92      0.00         0.05
# 3     9.4  37733.0  9829     X360      0.08      0.03      0.00         0.01
# 4     9.5  55637.0    17      PS3      7.01      9.27      0.97         4.14
# ..    ...      ...   ...      ...       ...       ...       ...          ...
# 653   8.6   3684.0  7718       GC      0.15      0.04      0.00         0.01
# 654   8.1   2177.0   405      PS2      1.44      1.01      0.57         0.30
# 655   8.3   1219.0  3352      PS3      0.22      0.25      0.04         0.09
# 656   8.3   1219.0  3956     X360      0.27      0.15      0.04         0.04
# 657   8.3   1219.0  9789       PC      0.00      0.10      0.00         0.02
#
#      Global_Sales
# 0           20.81
# 1            1.95
# 2            0.98
# 3            0.12
# 4           21.40
# ..            ...
# 653          0.20
# 654          3.33
# 655          0.60
# 656          0.50
# 657          0.12
#
# [658 rows x 12 columns]
