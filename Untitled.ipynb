# %% [markdown]
# ### appendix
#
# > <a href=#imports>Import Libraries</a>
#
# > <a href=#webscrabing>Web Scraping</a>
#
# > <a href=#merge>Merging Data</a>
#
# > <a href=#EDA>Explratory Data Analysis (EDA)</a>
#
# > <a href=#LR>Linear Regression</a>
#
# > <a href=#LR>Conclusion</a>

# %% [markdown]
# # <a name=imports>Import Libraries</a>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # <a name=webscrabing>Web Scraping</a>

# %%
url = "https://www.imdb.com/search/title/?title_type=video_game"

response = requests.get(url)
response.status_code
page = response.text
soup = BeautifulSoup(page, "lxml")

# %%
def clean_num(s):
    """cleans text scraped from website
    
    Parameters:
    s (String): raw text

    Returns:
    String: cleaned digit text

    """ 

    if s is None:
        return s
    return "".join(re.findall('\d*\.?\d+',s))

def get_data(block, tag, class_text):
    """fetch data from tag and its associated class
    
    Parameters:
    block (int): Book item 
    tag (String): tag for element we want to fetch
    class_text (String): class for element we want to fetch

    Returns:
    String: data text fetched

    """ 
    try:
        return block.find(tag, class_ = class_text).text.replace('(','').replace(')','')
    except AttributeError:
        return ""
    return

def get_data_a_tag(i, tag, class_text):    
    try:
        return i.find(tag, class_ = class_text).a.text
    except AttributeError:
        return ""
    return
def get_data_strong_tag(i, tag, class_text):    
    try:
        return i.find(tag, class_ = class_text).strong.text
    except AttributeError:
        return ""
    return
def get_data_descr(i, tag, class_text):    
    try:
        return i.find_all(tag, class_ = class_text)[1].text.strip()
    except AttributeError:
        return ""
    return


def get_data_votes(i, tag, class_text):    
    try:
        return i.find(tag, class_ = class_text).text.split()[1].replace(',','')
    except AttributeError:
        return ""
    return

# %%
    
Vgame_list = []

for i in (soup.find_all('div','lister-item mode-advanced')):
    Name = get_data_a_tag(i, "h3","lister-item-header")
    year = get_data(i, "span", "lister-item-year text-muted unbold").split()[0]
    Gtype = get_data(i, "p", "text-muted").strip()
    rate = clean_num(get_data_strong_tag(i, "div","ratings-bar"))
    votes = clean_num(get_data_votes(i, "p","sort-num_votes-visible"))
    
    headers = ['Name', 'year', 'game_type', 'rate','votes']
    Vgame_dict = dict(zip(headers, [ Name,
                                    year,
                                    Gtype,
                                    rate,
                                    votes]))
    Vgame_list.append(Vgame_dict)

# %%
vedioGame = pd.DataFrame(Vgame_list) #transpose
vedioGame
# Out:
#                                                  Name   year  \
# 0                    Marvel's Guardians of the Galaxy   2021
# 1                       Grand Theft Auto: San Andreas   2004
# 2                              Red Dead Redemption II   2018
# 3                              Call of Duty: Vanguard   2021
# 4                                       Halo Infinite   2021
# 5                                  Grand Theft Auto V   2013
# 6                                           Far Cry 6   2021
# 7                                     Death Stranding   2019
# 8                             The Last of Us: Part II   2020
# 9                                        Ghostbusters   2009
# 10                        Grand Theft Auto: Vice City   2002
# 11                                   Battlefield 2042   2021
# 12                                     Cyberpunk 2077   2020
# 13                                  League of Legends   2009
# 14                                         Spider-Man   2018
# 15                              Detroit: Become Human   2018
# 16                          Spider-Man: Miles Morales   2020
# 17                                     The Last of Us   2013
# 18                          Assassin's Creed Valhalla   2020
# 19                              Resident Evil Village   2021
# 20                       Star Wars Jedi: Fallen Order   2019
# 21                                         Until Dawn   2015
# 22                  The Dark Pictures: House of Ashes   2021
# 23                                         God of War   2018
# 24                                  Ghost of Tsushima   2020
# 25                               Grand Theft Auto III   2001
# 26                        The Elder Scrolls V: Skyrim   2011
# 27                                Grand Theft Auto IV   2008
# 28                              Wiedzmin 3: Dziki Gon   2015
# 29                                  Horizon Zero Dawn   2017
# 30                              Batman: Arkham Knight   2015
# 31                                          Far Cry 3   2012
# 32                                       It Takes Two   2021
# 33                                  Marvel's Avengers   2020
# 34                         Uncharted 4: A Thief's End   2016
# 35  Grand Theft Auto: The Trilogy - The Definitive...   2021
# 36                           Final Fantasy VII Remake   2020
# 37                                        Mass Effect   2007
# 38                                Red Dead Redemption   2010
# 39                     Command & Conquer: Red Alert 3   2008
# 40                                        Squadron 42  Video
# 41                     Mass Effect: Legendary Edition   2021
# 42                       Call of Duty: Modern Warfare   2019
# 43                                     Genshin Impact   2020
# 44                                          Fallout 4   2015
# 45                                         L.A. Noire   2011
# 46                          Mafia: Definitive Edition   2020
# 47                                          Far Cry 5   2018
# 48                                Batman: Arkham City   2011
# 49                               God of War: Ragnarök   2022
#
#                                             game_type rate  votes
# 0                           Action, Adventure, Comedy  9.1    869
# 1                                       Action, Crime  9.4  37712
# 2                            Action, Adventure, Crime  9.7  28793
# 3                          Action, Adventure, History  6.4    472
# 4   Action, Adventure, Sci-Fi            \n|\nComp...
# 5                                Action, Crime, Drama  9.5  55593
# 6                                   Action, Adventure  8.1    783
# 7                            Action, Adventure, Drama  8.9   6966
# 8               banned\n|\n\nAction, Adventure, Drama  8.3  26120
# 9                           Action, Adventure, Comedy  8.5   2864
# 10                               Action, Crime, Drama  9.2  25138
# 11                          Action, Adventure, Sci-Fi  3.7    168
# 12                               Action, Crime, Drama  7.9   5906
# 13                         Action, Adventure, Fantasy  7.3   2423
# 14                         Action, Adventure, Fantasy  9.2  16855
# 15                           Action, Adventure, Drama  9.2  14228
# 16                           Action, Adventure, Crime  8.5   3467
# 17                           Action, Adventure, Drama  9.7  55780
# 18                         Action, Adventure, Fantasy  8.2   2715
# 19                         Action, Adventure, Fantasy  8.8   3227
# 20                           Action, Adventure, Drama  8.6   8476
# 21                          Horror, Mystery, Thriller  8.8  12965
# 22                          Action, Adventure, Horror  7.9    485
# 23                           Action, Adventure, Drama  9.6  21358
# 24                           Action, Adventure, Drama  9.3   6007
# 25                               Action, Crime, Drama  8.7  15025
# 26                         Action, Adventure, Fantasy  9.4  27867
# 27                               Action, Crime, Drama  8.9  33311
# 28              banned\n|\n\nAction, Adventure, Drama  9.7  23072
# 29                         Action, Adventure, Mystery  9.1  11652
# 30                           Action, Adventure, Crime  9.0  16671
# 31                                  Action, Adventure  8.9  17546
# 32                           Adventure, Comedy, Drama  9.3    915
# 33                         Action, Adventure, Fantasy  6.4   1822
# 34                           Action, Adventure, Drama  9.5  24988
# 35                               Action, Crime, Drama  3.2    292
# 36                         Action, Adventure, Fantasy  9.1   2972
# 37                          Action, Adventure, Sci-Fi  9.2  17355
# 38              banned\n|\n\nAction, Adventure, Crime  9.4  25143
# 39                                Action, Sci-Fi, War  7.6   1977
# 40           Action, Sci-Fi            \n|\nAnnounced
# 41                                             Sci-Fi  9.7    731
# 42                        Action, Adventure, Thriller  8.4   4303
# 43                         Action, Adventure, Fantasy  7.9    706
# 44                           Action, Adventure, Drama  8.6  11841
# 45                  banned\n|\n\nAction, Crime, Drama  8.7  14877
# 46                               Action, Crime, Drama  8.5   1692
# 47                         Action, Adventure, Western  8.0   5899
# 48                           Action, Adventure, Crime  9.4  28738
# 49  Action, Adventure, Drama            \n|\nPost-...

# %%
def get_movie_dict(link):

    #Create full url to scrape
    url =link
    
    #Request HTML and parse
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")
  
    
    for i in (soup.find_all('div','lister-item mode-advanced')):        
        Name = get_data_a_tag(i, "h3","lister-item-header")
        year = get_data(i, "span", "lister-item-year text-muted unbold").split()[0]
        Gtype = get_data(i, "p", "text-muted").strip()
        rate = clean_num(get_data_strong_tag(i, "div","ratings-bar"))
        votes = clean_num(get_data_votes(i, "p","sort-num_votes-visible"))
    
        headers = ['Name', 'year', 'game_type', 'rate','votes']
        #Create game vedio dictionary and return
        movie_dict = dict(zip(headers, [ Name,
                                    year,
                                    Gtype,
                                    rate,
                                    votes]))
        Vgame_list.append(movie_dict) 

    return movie_dict

# %%
get_movie_dict("https://www.imdb.com/search/title/?title_type=video_game&start=51&ref_=adv_nxt")
# Out:
# {'Name': 'Teiruzu obu Araizu',
#  'year': '2021',
#  'game_type': 'Action, Adventure, Fantasy',
#  'rate': '8.7',
#  'votes': '141'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=101&ref_=adv_nxt')
# Out:
# {'Name': "Assassin's Creed II",
#  'year': '2009',
#  'game_type': 'Action, Adventure, Fantasy',
#  'rate': '9.1',
#  'votes': '21842'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=151&ref_=adv_nxt')
# Out:
# {'Name': 'Lost Judgment',
#  'year': '2021',
#  'game_type': 'Action, Adventure, Crime',
#  'rate': '8.8',
#  'votes': '90'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=201&ref_=adv_nxt')
# Out:
# {'Name': 'Devil May Cry 5',
#  'year': '2019',
#  'game_type': 'Action, Adventure, Fantasy',
#  'rate': '8.6',
#  'votes': '1723'}

# %%
get_movie_dict('https://www.imdb.com/search/title/?title_type=video_game&start=251&ref_=adv_nxt')
# Out:
# {'Name': 'Outlast 2',
#  'year': '2017',
#  'game_type': 'Horror, Mystery, Thriller',
#  'rate': '7.6',
#  'votes': '1935'}

# %%
vedioGamePages = pd.DataFrame(Vgame_list) #transpose
vedioGamePages
# Out:
#                                  Name  year  \
# 0    Marvel's Guardians of the Galaxy  2021
# 1       Grand Theft Auto: San Andreas  2004
# 2              Red Dead Redemption II  2018
# 3              Call of Duty: Vanguard  2021
# 4                       Halo Infinite  2021
# ..                                ...   ...
# 295                 The Wolf Among Us  2013
# 296         Kingdom Come: Deliverance  2018
# 297            Perusona 5: Za roiyaru  2019
# 298         True Crime: New York City  2005
# 299                         Outlast 2  2017
#
#                                              game_type rate  votes
# 0                            Action, Adventure, Comedy  9.1    869
# 1                                        Action, Crime  9.4  37712
# 2                             Action, Adventure, Crime  9.7  28793
# 3                           Action, Adventure, History  6.4    472
# 4    Action, Adventure, Sci-Fi            \n|\nComp...
# ..                                                 ...  ...    ...
# 295                               Action, Crime, Drama  8.9   6572
# 296                          Adventure, Drama, History  8.3   1003
# 297                         Action, Adventure, Fantasy  9.6    805
# 298                           Action, Adventure, Crime  7.0    897
# 299                          Horror, Mystery, Thriller  7.6   1935
#
# [300 rows x 5 columns]

# %%
vedioGamePages.to_csv('videogame.csv')

# %%
vedioGamePages.Name=vedioGamePages.Name.str.lower()
vedioGamePages.head()
# Out:
#                                Name  year  \
# 0  marvel's guardians of the galaxy  2021
# 1     grand theft auto: san andreas  2004
# 2            red dead redemption ii  2018
# 3            call of duty: vanguard  2021
# 4                     halo infinite  2021
#
#                                            game_type rate  votes
# 0                          Action, Adventure, Comedy  9.1    869
# 1                                      Action, Crime  9.4  37712
# 2                           Action, Adventure, Crime  9.7  28793
# 3                         Action, Adventure, History  6.4    472
# 4  Action, Adventure, Sci-Fi            \n|\nComp...

# %%
vedioGamePages
# Out:
#                                  Name  year  \
# 0    marvel's guardians of the galaxy  2021
# 1       grand theft auto: san andreas  2004
# 2              red dead redemption ii  2018
# 3              call of duty: vanguard  2021
# 4                       halo infinite  2021
# ..                                ...   ...
# 295                 the wolf among us  2013
# 296         kingdom come: deliverance  2018
# 297            perusona 5: za roiyaru  2019
# 298         true crime: new york city  2005
# 299                         outlast 2  2017
#
#                                              game_type rate  votes
# 0                            Action, Adventure, Comedy  9.1    869
# 1                                        Action, Crime  9.4  37712
# 2                             Action, Adventure, Crime  9.7  28793
# 3                           Action, Adventure, History  6.4    472
# 4    Action, Adventure, Sci-Fi            \n|\nComp...
# ..                                                 ...  ...    ...
# 295                               Action, Crime, Drama  8.9   6572
# 296                          Adventure, Drama, History  8.3   1003
# 297                         Action, Adventure, Fantasy  9.6    805
# 298                           Action, Adventure, Crime  7.0    897
# 299                          Horror, Mystery, Thriller  7.6   1935
#
# [300 rows x 5 columns]

# %% [markdown]
# ### 1.Load the dataframe2

# %%
df=pd.read_csv('vgsales.csv') #data from kaggle

# %%
df.Name=df.Name.str.lower()
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                wii sports      Wii  2006.0        Sports  Nintendo
# 1     2         super mario bros.      NES  1985.0      Platform  Nintendo
# 2     3            mario kart wii      Wii  2008.0        Racing  Nintendo
# 3     4         wii sports resort      Wii  2009.0        Sports  Nintendo
# 4     5  pokemon red/pokemon blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# # <a name=merge>Merging Data</a>

# %%
mer_vidgame=vedioGamePages.merge(df, on='Name')

# %%
mer_vidgame.head()
# Out:
#                             Name  year             game_type rate  votes  \
# 0  grand theft auto: san andreas  2004         Action, Crime  9.4  37712
# 1  grand theft auto: san andreas  2004         Action, Crime  9.4  37712
# 2  grand theft auto: san andreas  2004         Action, Crime  9.4  37712
# 3  grand theft auto: san andreas  2004         Action, Crime  9.4  37712
# 4             grand theft auto v  2013  Action, Crime, Drama  9.5  55593
#
#    Rank Platform    Year   Genre             Publisher  NA_Sales  EU_Sales  \
# 0    18      PS2  2004.0  Action  Take-Two Interactive      9.43      0.40
# 1   875       XB  2005.0  Action  Take-Two Interactive      1.26      0.61
# 2  2122       PC  2005.0  Action  Take-Two Interactive      0.00      0.92
# 3  9829     X360  2008.0  Action  Take-Two Interactive      0.08      0.03
# 4    17      PS3  2013.0  Action  Take-Two Interactive      7.01      9.27
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      0.41        10.57         20.81
# 1      0.00         0.09          1.95
# 2      0.00         0.05          0.98
# 3      0.00         0.01          0.12
# 4      0.97         4.14         21.40

# %%
df1=pd.DataFrame(mer_vidgame)

# %% [markdown]
# # <a name=EDA>Explratory data analysis(EDA)</a>

# %%
 # drop column that we don't use
df1.drop([ 'Year', 'Genre','Publisher'], axis=1, inplace=True)

# %%
df1.shape
# Out:
# (406, 12)

# %%
df1['game_type'].tolist()
# Out:
# ['Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Comedy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Horror, Mystery, Thriller',
#  'Action, Adventure, Drama',
#  'banned\n|\n\nAction, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'banned\n|\n\nAction, Adventure, Crime',
#  'banned\n|\n\nAction, Adventure, Crime',
#  'Action, Sci-Fi, War',
#  'Action, Sci-Fi, War',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'banned\n|\n\nAction, Crime, Drama',
#  'banned\n|\n\nAction, Crime, Drama',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Mystery',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Sci-Fi',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Comedy, Drama',
#  'Action, Adventure, Family',
#  'Action, Adventure, Family',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Drama, Mystery, Sci-Fi',
#  'Drama, Mystery, Sci-Fi',
#  'Drama, Mystery, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Drama            \n|\nAnnounced',
#  'Action, Adventure, Drama            \n|\nAnnounced',
#  'Action, Adventure, Drama            \n|\nAnnounced',
#  'Action, Adventure, Drama            \n|\nAnnounced',
#  'Action, Adventure, Drama            \n|\nAnnounced',
#  'Action, Adventure, Drama            \n|\nAnnounced',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'banned\n|\n\nCrime, Drama, Mystery',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Horror, Sci-Fi, Thriller',
#  'Horror, Sci-Fi, Thriller',
#  'Horror, Sci-Fi, Thriller',
#  'Horror, Sci-Fi, Thriller',
#  'Horror, Sci-Fi, Thriller',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Horror, Sci-Fi',
#  'Action, Crime, Thriller',
#  'Action, Crime, Thriller',
#  'Action, Mystery, Sci-Fi',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, War',
#  'Action, War',
#  'Action, War',
#  'Action, War',
#  'Action, War',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Thriller',
#  'banned\n|\n\nAction, Adventure, Thriller',
#  'banned\n|\n\nAction, Adventure, Thriller',
#  'banned\n|\n\nAction, Adventure, Thriller',
#  'banned\n|\n\nAction, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Thriller',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Adventure, History',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Sci-Fi',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Drama, Horror, Mystery',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Drama',
#  'Action, Comedy, Horror',
#  'Action, Comedy, Horror',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Animation, Action, Sport',
#  'Action, Adventure, Fantasy',
#  'Action, Crime, Sci-Fi',
#  'Action, Crime, Sci-Fi',
#  'Action, Crime, Sci-Fi',
#  'Action, Crime, Sci-Fi',
#  'Action, Crime, Sci-Fi',
#  'Action, Crime, Sci-Fi',
#  'Action, Mystery, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Horror, Mystery',
#  'Action, Horror, Mystery',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'banned\n|\n\nAction, Adventure, Comedy',
#  'banned\n|\n\nAction, Adventure, Comedy',
#  'banned\n|\n\nAction, Adventure, Comedy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, War',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Horror',
#  'Action, Adventure, Fantasy',
#  'Animation, Action, Adventure',
#  'Animation, Action, Adventure',
#  'Animation, Action, Adventure',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Comedy',
#  'Action, Adventure, Sci-Fi',
#  'Action, Adventure, Sci-Fi',
#  'Action, Horror, War',
#  'Action, Horror, War',
#  'Action, Horror, War',
#  'Action, Horror, War',
#  'Action, Horror, War',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Fantasy',
#  'Action, Adventure, Crime',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Sci-Fi',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Crime, Drama',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime',
#  'Action, Adventure, Crime']

# %%
df1['game_type']=df1['game_type'].str.replace('banned\n|\n\n','')
df1['game_type']=df1['game_type'].str.replace('\n|\nAnnounced','')
df1['game_type']=df1['game_type'].str.replace('|','')
df1['game_type']=df1['game_type'].str.replace('Announced','')
# Out:
# <ipython-input-24-a6128a77383f>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['game_type']=df1['game_type'].str.replace('banned\n|\n\n','')
# <ipython-input-24-a6128a77383f>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['game_type']=df1['game_type'].str.replace('\n|\nAnnounced','')
# <ipython-input-24-a6128a77383f>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df1['game_type']=df1['game_type'].str.replace('|','')

# %%
df1
# Out:
#                               Name  year                 game_type rate  \
# 0    grand theft auto: san andreas  2004             Action, Crime  9.4
# 1    grand theft auto: san andreas  2004             Action, Crime  9.4
# 2    grand theft auto: san andreas  2004             Action, Crime  9.4
# 3    grand theft auto: san andreas  2004             Action, Crime  9.4
# 4               grand theft auto v  2013      Action, Crime, Drama  9.5
# ..                             ...   ...                       ...  ...
# 401              the wolf among us  2013      Action, Crime, Drama  8.9
# 402              the wolf among us  2013      Action, Crime, Drama  8.9
# 403      true crime: new york city  2005  Action, Adventure, Crime  7.0
# 404      true crime: new york city  2005  Action, Adventure, Crime  7.0
# 405      true crime: new york city  2005  Action, Adventure, Crime  7.0
#
#      votes   Rank Platform  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0    37712     18      PS2      9.43      0.40      0.41        10.57
# 1    37712    875       XB      1.26      0.61      0.00         0.09
# 2    37712   2122       PC      0.00      0.92      0.00         0.05
# 3    37712   9829     X360      0.08      0.03      0.00         0.01
# 4    55593     17      PS3      7.01      9.27      0.97         4.14
# ..     ...    ...      ...       ...       ...       ...          ...
# 401   6572  11939      PSV      0.05      0.00      0.00         0.02
# 402   6572  13683     X360      0.01      0.03      0.00         0.00
# 403    897   2723      PS2      0.57      0.02      0.07         0.09
# 404    897   6244       XB      0.21      0.06      0.00         0.01
# 405    897   8266       GC      0.13      0.03      0.00         0.00
#
#      Global_Sales
# 0           20.81
# 1            1.95
# 2            0.98
# 3            0.12
# 4           21.40
# ..            ...
# 401          0.07
# 402          0.04
# 403          0.76
# 404          0.28
# 405          0.17
#
# [406 rows x 12 columns]

# %%
df1['year'] = pd.to_numeric(df1['year'], errors='coerce')

# %%
df1['rate'] = pd.to_numeric(df1['rate'], errors='coerce')

# %%
df1['votes'] = pd.to_numeric(df1['votes'], errors='coerce')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406 entries, 0 to 405
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          406 non-null    object
#  1   year          400 non-null    float64
#  2   game_type     406 non-null    object
#  3   rate          400 non-null    float64
#  4   votes         400 non-null    float64
#  5   Rank          406 non-null    int64
#  6   Platform      406 non-null    object
#  7   NA_Sales      406 non-null    float64
#  8   EU_Sales      406 non-null    float64
#  9   JP_Sales      406 non-null    float64
#  10  Other_Sales   406 non-null    float64
#  11  Global_Sales  406 non-null    float64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 41.2+ KB

# %%
df1.describe()
# Out:
#               year        rate         votes          Rank    NA_Sales  \
# count   400.000000  400.000000    400.000000    406.000000  406.000000
# mean   2010.690000    8.361500  10302.575000   3300.448276    1.188498
# std       4.482648    0.743539   9602.851064   3820.563391    1.731449
# min    1997.000000    6.400000    536.000000     17.000000    0.000000
# 25%    2008.000000    8.000000   4106.000000    455.000000    0.170000
# 50%    2012.000000    8.400000   6951.000000   1891.500000    0.555000
# 75%    2014.000000    8.925000  14673.000000   4508.500000    1.407500
# max    2023.000000    9.700000  55780.000000  16375.000000    9.670000
#
#          EU_Sales    JP_Sales  Other_Sales  Global_Sales
# count  406.000000  406.000000   406.000000    406.000000
# mean     0.775369    0.067291     0.294064      2.325493
# std      1.083115    0.185191     0.663309      3.225921
# min      0.000000    0.000000     0.000000      0.010000
# 25%      0.130000    0.000000     0.040000      0.430000
# 50%      0.400000    0.000000     0.110000      1.085000
# 75%      0.977500    0.060000     0.310000      3.070000
# max      9.270000    2.020000    10.570000     21.400000

# %%
df1.to_csv('merge_video_game.csv')
